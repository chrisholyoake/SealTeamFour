# %%
import pandas as pd
import numpy as np
import csv
import matplotlib as plt

# %%
# importing dataframes from 'project_dataclean'
city_data = pd.read_csv("Resources/Clean_Data/CityData/city_data_rent_murders_population.csv")
county_data = pd.read_csv("Resources/Clean_Data/CountyData/county_data_food_unemployment.csv")

# %%
county_data.head()
# Out:
#    Unnamed: 0 State     County  Population People 1/2 Mile and More  \
# 0           0    SC  Abbeville     25417.0              24360.33225
# 1           1    LA     Acadia     61773.0              44415.58912
# 2           2    VA   Accomack     33164.0              30163.64972
# 3           3    ID        Ada    392365.0              299582.0814
# 4           4    IA      Adair      7682.0              5496.847853
#
#   People 1 Mile and More  People 10 Miles and More  People 20 Miles and More  \
# 0            21510.19482               5176.769348                  0.000000
# 1            32874.79307                625.970960                  0.000000
# 2            26847.70482                727.000007                  0.000000
# 3            137142.5048                209.471626                  1.931907
# 4             4916.79045                605.066287                  0.000000
#
#   Civilian labour force Employed poulation Unemployed population  \
# 0                10,349              9,637                   712
# 1                25,858             24,088                 1,770
# 2                15,877             15,012                   865
# 3               217,052            209,058                 7,994
# 4                 4,226              4,089                   137
#
#    Rate of Unemployment
# 0                   7.0
# 1                   7.0
# 2                   5.0
# 3                   4.0
# 4                   3.0

# %%
city_data.head()
# Out:
#    Unnamed: 0         City State Average Rent  Murders Population  \
# 0           0     New York    NY      $2,978       266  8,550,405
# 1           1  Los Angeles    CA      $3,195       209  3,971,883
# 2           2      Chicago    IL      $1,758       378  2,720,546
# 3           3      Houston    TX      $1,490       191  2,296,224
# 4           4  San Antonio    TX      $1,115        78  1,469,845
#
#    Murder Rate (per 100,000)
# 0                        2.9
# 1                        5.2
# 2                       19.7
# 3                        9.2
# 4                        7.6
